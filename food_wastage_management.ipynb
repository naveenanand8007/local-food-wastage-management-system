# %%
import pandas as pd

# %%
providers = pd.read_csv("providers_data.csv")
receivers = pd.read_csv("receivers_data.csv")
food_listings = pd.read_csv("food_listings_data.csv")
claims = pd.read_csv("claims_data.csv")

# %%
import sqlite3

# %%
# Database connection
conn = sqlite3.connect("food_wastage.db")
cursor = conn.cursor()

# %%
# Creating tables
cursor.execute('''
    CREATE TABLE IF NOT EXISTS providers (
        Provider_ID INTEGER PRIMARY KEY,
        Name TEXT,
        Type TEXT,
        Address TEXT,
        City TEXT,
        Contact TEXT
    )
''')

# %%
cursor.execute('''
    CREATE TABLE IF NOT EXISTS receivers (
        Receiver_ID INTEGER PRIMARY KEY,
        Name TEXT,
        Type TEXT,
        City TEXT,
        Contact TEXT
    )
''')

# %%
cursor.execute('''
    CREATE TABLE IF NOT EXISTS food_listings (
        Food_ID INTEGER PRIMARY KEY,
        Food_Name TEXT,
        Quantity TEXT,
        Expiry_Date TEXT,
        Provider_ID INTEGER,
        Provider_Type TEXT,      
        Location TEXT,
        Food_Type TEXT,
        Meal_Type TEXT,
    FOREIGN KEY (Provider_ID) REFERENCES providers(Provider_ID)
    )
''')

# %%
cursor.execute('''
    CREATE TABLE IF NOT EXISTS claims (
        Claim_ID INTEGER PRIMARY KEY,
        Food_ID INTEGER,
        Receiver_ID INTEGER,
        Status TEXT,
        TimeStamp TEXT,
        FOREIGN KEY (Food_ID) REFERENCES food_listings(Food_ID),
        FOREIGN KEY (Receiver_ID) REFERENCES receivers(Receiver_ID)
        
    )
''')

# %%
for index, row in providers.iterrows():
    cursor.execute("""
        INSERT OR IGNORE INTO providers (Provider_ID, Name, Type, Address, City, Contact)
        VALUES (?, ?, ?, ?, ?, ?)
    """, tuple(row))

conn.commit()

# %%
for _, row in receivers.iterrows():
    cursor.execute("""
        INSERT OR IGNORE INTO receivers (Receiver_ID, Name, Type, City, Contact)
        VALUES (?, ?, ?, ?, ?)
    """, tuple(row))

conn.commit()

# %%
for _, row in food_listings.iterrows():
    cursor.execute("""
        INSERT OR IGNORE INTO food_listings 
        (Food_ID, Food_Name, Quantity, Expiry_Date, Provider_ID, Provider_Type, Location, Food_Type, Meal_Type)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
    """, tuple(row))

conn.commit()

# %%
for _, row in claims.iterrows():
    cursor.execute("""
        INSERT OR IGNORE INTO claims 
        (Claim_ID, Food_ID, Receiver_ID, Status, TimeStamp)
        VALUES (?, ?, ?, ?, ?)
    """, tuple(row))

conn.commit()

# %%
# SQL query to get the city with the highest number of providers
query = """
    SELECT City, COUNT(*) AS Provider_Count
    FROM providers
    GROUP BY City
    ORDER BY Provider_Count DESC
    LIMIT 1;
"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["City", "Provider_Count"])
df
# Out:
#                        City  Provider_Count
# 0  South Christopherborough               3

# %%
#1 How many food providers and receivers are there in each city?

query = """
    SELECT
    COALESCE(p.City, r.City) AS City,
    COUNT(DISTINCT p.provider_id) AS provider_count,
    COUNT(DISTINCT r.receiver_id) AS receiver_count
FROM providers p
FULL OUTER JOIN receivers r
    ON p.City = r.City
GROUP BY COALESCE(p.City, r.City)
ORDER BY City;
"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["City", "provider_count", "receiver_count"])

# %%
#2

query = """
    SELECT 
    provider_type,
    SUM(quantity) AS total_quantity
FROM food_listings
GROUP BY provider_type order by total_quantity DESC LIMIT 1;

"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Provider_Type", "total_quantity"])
df
# Out:
#   Provider_Type  total_quantity
# 0    Restaurant            6923

# %%
#3

query = """
   SELECT City, Contact from providers where City == "New Jessica"

"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Provider_Type", "total_quantity"])
df
# Out:
#   Provider_Type   total_quantity
# 0   New Jessica  +1-600-220-0480

# %%
#4

query = """
   WITH claim_counts AS (
    SELECT 
        r.Receiver_ID,
        r.Name,
        COUNT(c.Claim_ID) AS claim_count
    FROM 
        receivers r
    LEFT JOIN 
        claims c
    ON 
        r.Receiver_ID = c.Receiver_ID
    GROUP BY 
        r.Receiver_ID, r.Name
)
SELECT *
FROM claim_counts
WHERE claim_count = (
    SELECT MAX(claim_count) FROM claim_counts
);


"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Reciever_ID","Name", "claim_count"])
df
# Out:
#    Reciever_ID               Name  claim_count
# 0          276       Scott Hunter            5
# 1          371  William Frederick            5
# 2          742       Matthew Webb            5
# 3          800     Anthony Garcia            5

# %%
#5

query = """
   SELECT 
    f.provider_id,
    p.Name,
    SUM(f.quantity) AS total_quantity
FROM 
    food_listings f
JOIN 
    providers p
ON 
    f.provider_id = p.provider_id
GROUP BY 
    f.provider_id, p.Name;

"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Provider_ID","Name", "total_quantity"])

# %%
#6

query = """
WITH location_counts AS (
    SELECT 
        Location as city,
        COUNT(*) AS listing_count
    FROM 
        food_listings
    GROUP BY 
        Location
)
SELECT *
FROM location_counts
WHERE listing_count = (
    SELECT MAX(listing_count) 
    FROM location_counts
);



"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["city","listing_count"])
df
# Out:
#             city  listing_count
# 0      New Carol              6
# 1  South Kathryn              6

# %%
#7

query = """
SELECT 
    Food_Name,
    COUNT(*) AS listing_count,
    SUM(Quantity) AS total_quantity
FROM 
    food_listings
GROUP BY 
    Food_Name
ORDER BY 
    listing_count DESC;


"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Food_Name","listing_count", "total_quantity"])
df
# Out:
#     Food_Name  listing_count  total_quantity
# 0        Rice            114            3133
# 1        Soup            111            2819
# 2       Salad            105            2765
# 3       Dairy            103            2765
# 4     Chicken            103            2324
# 5       Pasta            102            2626
# 6       Bread             98            2726
# 7        Fish             92            2081
# 8  Vegetables             91            2342
# 9      Fruits             81            2213

# %%
#8 

query = """
SELECT 
    f.Food_Name,
    COUNT(*) AS claim_count
FROM 
    claims c
JOIN 
    food_listings f
ON 
    c.Food_ID = f.Food_ID
GROUP BY 
    f.Food_Name;


"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Food_Name","claim_count"])
df
# Out:
#     Food_Name  claim_count
# 0       Bread           94
# 1     Chicken          102
# 2       Dairy          110
# 3        Fish          108
# 4      Fruits           71
# 5       Pasta           87
# 6        Rice          122
# 7       Salad          106
# 8        Soup          114
# 9  Vegetables           86

# %%
#9

query = """
WITH completed_counts AS (
    SELECT 
        f.Provider_ID,
        COUNT(*) AS completed_claims
    FROM 
        food_listings f
    JOIN 
        claims c
        ON f.Food_ID = c.Food_ID
    WHERE 
        c.Status = 'Completed'
    GROUP BY 
        f.Provider_ID
)
SELECT 
    p.Provider_ID,
    p.Name,
    cc.completed_claims
FROM 
    completed_counts cc
JOIN 
    providers p
    ON cc.Provider_ID = p.Provider_ID
WHERE 
    cc.completed_claims = (
        SELECT MAX(completed_claims) FROM completed_counts
    );


"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Food_ID","Name","completed_count"])
df
# Out:
#    Food_ID         Name  completed_count
# 0      709  Barry Group                5

# %%
#10

query = """
SELECT 
    Status,
    COUNT(*) AS claim_count,
    ROUND( (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM claims)), 2 ) AS percentage
FROM 
    claims
GROUP BY 
    Status;

"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Status","claim_count","percentage"])
df
# Out:
#       Status  claim_count  percentage
# 0  Cancelled          336        33.6
# 1  Completed          339        33.9
# 2    Pending          325        32.5

# %%
#10

query = """
SELECT 
    Status,
    COUNT(*) AS claim_count,
    ROUND( (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM claims)), 2 ) AS percentage
FROM 
    claims
GROUP BY 
    Status;

"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Status","claim_count","percentage"])
df
# Out:
#       Status  claim_count  percentage
# 0  Cancelled          336        33.6
# 1  Completed          339        33.9
# 2    Pending          325        32.5

# %%
#11

query = """
SELECT 
    r.Receiver_ID,
    r.Name,
    ROUND(AVG(f.Quantity), 2) AS avg_claimed_quantity
FROM 
    claims c
JOIN 
    food_listings f
    ON c.Food_ID = f.Food_ID
JOIN 
    receivers r
    ON c.Receiver_ID = r.Receiver_ID
GROUP BY 
    r.Receiver_ID, r.Name;

"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Receiver_ID","Name","avg_claimed_quantity"])
df

# %%
#12

query = """
SELECT 
    f.Meal_Type,
    COUNT(c.Claim_ID) AS claim_count
FROM 
    claims c
JOIN 
    food_listings f
    ON c.Food_ID = f.Food_ID
GROUP BY 
    f.Meal_Type
ORDER BY 
    claim_count DESC
LIMIT 1;

"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Meal_Type","claim_count"])
df
# Out:
#    Meal_Type  claim_count
# 0  Breakfast          278

# %%
#13

query = """
SELECT 
    f.Provider_ID,
    p.Name,
    SUM(f.Quantity) AS total_quantity
FROM 
    food_listings f
JOIN 
    providers p
    ON f.Provider_ID = p.Provider_ID
GROUP BY 
    f.Provider_ID, p.Name
ORDER BY 
    p.Provider_ID;

"""

cursor.execute(query)
result = cursor.fetchall()

# Convert result into a DataFrame for better readability
df = pd.DataFrame(result, columns=["Provider_ID","Name","total_quantity"])
df
# Out:
#      Provider_ID                               Name  total_quantity
# 0              1                   Gonzales-Cochran              78
# 1              2        Nielsen, Johnson and Fuller              53
# 2              4         Clark, Prince and Williams              96
# 3              5                     Coleman-Farley              92
# 4              7                          Ortiz-Lee             114
# 5              9                         Nguyen Inc              21
# 6             10          Hall, Nguyen and Martinez              39
# 7             11           Flores, Jackson and Ford              27
# 8             14                        Nguyen-Tran              23
# 9             16                     Brown and Sons              47
# 10            17                         Miller Ltd              50
# 11            20                     Drake-Martinez              49
# 12            22                      Miller-Carter              25
# 13            24         Black, Collins and Richard               9
# 14            26                         Hansen Inc              19
# 15            29                      Andrews-Wiley              44
# 16            31                      Thompson-Kerr              72
# 17            33          Miranda, Wilcox and Short              45
# 18            34             Cooper, Smith and King              63
# 19            35                     Nguyen-Parsons              22
# 20            37                     Phelps-Schmidt              55
# 21            38                       Lawrence LLC              14
# 22            39                  Fernandez-Bridges              10
# 23            40                       Robinson PLC              27
# 24            41                         Kelly-Ware             123
# 25            42                          Austin-Yu              21
# 26            43       Martinez, Johnson and Torres              37
# 27            45          Butler, Kennedy and Cowan               4
# 28            46      Fisher, Hernandez and Webster              41
# 29            47                         Wong-Reese              98
# 30            48                        Conway-Barr               5
# 31            49           Miller, Braun and Graham              39
# 32            50                     Perez-Williams              45
# 33            52                         Buck-Carey              35
# 34            54        Bennett, Phillips and Green              64
# 35            55                       Wilson-Brown               4
# 36            56                         Morris Ltd              11
# 37            57                         Cook Group              79
# 38            58        Martin, Tyler and Wilkerson              55
# 39            59           Warner, White and Morris               6
# 40            60                    Parker-Campbell               5
# 41            62       Mitchell, Campbell and Jones              64
# 42            63      Fuller, Vincent and Fernandez              47
# 43            65                       Fletcher Inc              21
# 44            66                     Lambert-Wilson              57
# 45            67                        Shannon Ltd              22
# 46            68                      Sherman-Wolfe              20
# 47            71                      Jones-Edwards              75
# 48            72          Ward, Shepherd and Krause              42
# 49            74                       Johnston Ltd              46
# 50            76                        Clark-Estes               4
# 51            78                        Frazier LLC              38
# 52            82                   Carey-Richardson              32
# 53            84                       Atkins Group              46
# 54            85                         Larson Ltd              22
# 55            86                        Murphy-Boyd              35
# 56            87       Young, Townsend and Mccarthy              87
# 57            88          Oliver, Williams and Rich              15
# 58            90                       Miller Group              22
# 59            93        Davis, Vaughan and Shepherd              36
# 60            95                            Orr Inc              34
# 61            96           Pierce, Walsh and Rogers              39
# 62            97                        King-Snyder              47
# 63            98                     Hogan-Johnston              99
# 64           100                      Greene-Garcia              25
# 65           101                    Chambers-Waters              60
# 66           102       Hester, Bowers and Carpenter              26
# 67           103                    Russell-Summers              25
# 68           104                        Jackson LLC              11
# 69           107           Pollard, Tyler and Davis              27
# 70           108                       Williams-Cox              53
# 71           110                      Figueroa-Soto              43
# 72           111                        Ball-Church              40
# 73           112          Webb, Graves and Harrison              15
# 74           113      Anderson, Nicholson and Bruce              73
# 75           115                        Wells-Davis              33
# 76           116                   Mcdaniel-Morales              33
# 77           117              Morales, Wood and Cox              52
# 78           118                     Evans-Harrison              20
# 79           120                        Burns-Davis              19
# 80           122                   Mosley-Hernandez              20
# 81           123                  Stephens-Stephens              40
# 82           124    Allen, Zimmerman and Harrington               5
# 83           125                       Brown-Grimes              14
# 84           126        Jackson, Gonzalez and Smith              23
# 85           127                        Vasquez LLC              15
# 86           129                          Hicks Ltd              41
# 87           133                          Baker LLC              40
# 88           134                           Cook Ltd               4
# 89           135                         Dyer Group              53
# 90           138             Jones, Rojas and Brown              96
# 91           139                        Johnson-Ray             113
# 92           140                          Zhang LLC              76
# 93           142            Myers, Kelley and Riley               7
# 94           144          Johnson, Harris and White              37
# 95           146                        Hampton-Lee             116
# 96           148           Perry, Cabrera and Owens              11
# 97           150           Powers, Clark and Snyder              30
# 98           151                      Butler-Newman              30
# 99           152                        Rogers-Shaw              23
# 100          153                             Wu LLC              49
# 101          154                       Smith-Turner              59
# 102          155                     Bennett-Parker              18
# 103          157    Rodriguez, Walker and Singleton              50
# 104          158                     Shepherd Group              44
# 105          159          Wagner, Cole and Thompson              38
# 106          161                       Campbell LLC             123
# 107          162             Moore, Perez and Young              63
# 108          164                       Yu-Rodriguez              14
# 109          167                    Thompson-Turner               9
# 110          169                        Hines-Green              27
# 111          170            Peters, Chase and Davis              38
# 112          172     Parker, Macdonald and Espinoza              17
# 113          174         Gillespie, Foster and Boyd              13
# 114          175                          Olson Ltd              17
# 115          176                   Allen-Mccullough              88
# 116          177                     Turner-Ramirez               8
# 117          178                     Mcbride-Rogers              34
# 118          179             Lucas, Bush and Miller              50
# 119          181    Black, Montgomery and Hernandez              23
# 120          182                       Wilson-Ortiz              26
# 121          183                   Elliott-Stephens              38
# 122          184                    Norris-Townsend               1
# 123          185            Horn, Johnson and Moore              50
# 124          186                         Garner PLC               2
# 125          189                      Blackwell Ltd               4
# 126          191                        Grant-Davis              17
# 127          192       Hunter, Ballard and Caldwell             101
# 128          193            Chung, Morris and Craig              15
# 129          195                    Williams-Strong               4
# 130          196                       Owens-Taylor              67
# 131          198                         Bowman LLC              35
# 132          199           Clark, Evans and Navarro              39
# 133          200                       Turner-Woods              39
# 134          201                        Ramirez LLC              56
# 135          202                      Graham-Peters              45
# 136          204                          Lyons Inc               7
# 137          205                     Thompson Group              80
# 138          206                       Yoder-Murray              33
# 139          208      Miller, Johnson and Fernandez              92
# 140          210                       Jones-Miller              88
# 141          211        Anderson, Patrick and Scott              11
# 142          212         Dennis, Parker and Sanchez              46
# 143          213    Anderson, Robinson and Phillips               2
# 144          215                        Simmons Ltd              40
# 145          217                       Williams Ltd              46
# 146          221                   Richardson Group              64
# 147          222           Tran, Douglas and Harvey              28
# 148          223                    Hodges and Sons              34
# 149          224                     Hughes-Jackson              45
# 150          227                      Morse-Hoffman              28
# 151          228                       Stewart-Soto              33
# 152          230                     Phelps-Robbins              14
# 153          231                   Jackson-Robinson              70
# 154          232      Snyder, Caldwell and Campbell              68
# 155          234                      Sherman-Baker              29
# 156          235                      Gutierrez LLC              40
# 157          237        White, Crawford and Pearson              91
# 158          238                       Decker Group              50
# 159          239          Simpson, Thomas and Smith              31
# 160          240                       Marshall Ltd              49
# 161          241        Harper, Blake and Alexander              44
# 162          242                  Aguilar-Frederick              98
# 163          243                       Davis-Hurley              33
# 164          244                       Chan-Elliott              46
# 165          245                  Williams and Sons               4
# 166          247                     Shepherd-Yates              29
# 167          248          Oliver, Cross and Gilbert              50
# 168          249       Davis, Sanchez and Hernandez              33
# 169          251                       Carter-Jones             101
# 170          252                          Blair LLC              39
# 171          253                     Gonzales-Keith              73
# 172          254                        Huber Group              22
# 173          255         Chapman, Barrett and Lopez              49
# 174          257                        James Group              25
# 175          258                     Gonzales-Moore               1
# 176          261            Lopez, Davis and Duncan              39
# 177          262                  Bradford-Martinez             121
# 178          263             Lutz, Smith and Martin              31
# 179          264                   Holland and Sons              68
# 180          265                   Simmons-Mcdaniel              28
# 181          266                   Thomas-Carpenter              21
# 182          267                      Sherman-Garza              32
# 183          268     White, Hutchinson and Williams              29
# 184          270                    Harrison-Wilson              39
# 185          273                        Hammond LLC              46
# 186          274                      Shields-Moore              37
# 187          275          Floyd, Jones and Alvarado               9
# 188          276                      Hodge-Leblanc              58
# 189          277                     Ramos and Sons              38
# 190          279         Greene, Wood and Hernandez              14
# 191          282        Baker, Gardner and Callahan              42
# 192          284                           Cruz Inc              27
# 193          285                     Sanchez-Fisher              30
# 194          287                         Carr-Wells              68
# 195          288                     Carlson-Mathis              53
# 196          289                  Jenkins-Carpenter              37
# 197          290          Webb, Phillips and Garcia              81
# 198          292                        Lopez-Duffy              48
# 199          293                    Ibarra and Sons              42
# 200          295        Patterson, Harris and Kelly              30
# 201          301         Smith, Glover and Mcintyre               5
# 202          304                      Douglas-Colon              35
# 203          306         Evans, Wright and Mitchell             158
# 204          308                          Doyle LLC              93
# 205          310    Sullivan, Thornton and Peterson              43
# 206          312                      Garcia-Hunter              97
# 207          313                    Maldonado-Davis               7
# 208          314                     Wright-Mcclure              16
# 209          315                         Nelson LLC             142
# 210          316                      Johnson Group              27
# 211          319            Davila, Green and Avila              64
# 212          320                         Shah Group               5
# 213          321                     Williams-Boyle              40
# 214          323                     Peters-Johnson              26
# 215          324                      Roberts Group              42
# 216          326         Bender, Jordan and Bennett               8
# 217          327           Miller, Conner and Clark              34
# 218          328       Walker, Brennan and Townsend               8
# 219          330                      Holloway-Koch              59
# 220          331         Edwards, Johnson and Cross              25
# 221          332                            Cox LLC              99
# 222          333           Herrera, Fritz and Banks              23
# 223          334                       Cox-Mcintyre               6
# 224          335       Newman, Pearson and Mccarthy               7
# 225          336                       Mckinney LLC              18
# 226          337                       Hogan-Oliver               7
# 227          338                         Ibarra LLC              34
# 228          340            Barry, Powers and White              47
# 229          341                   Jenkins-Carrillo              13
# 230          342                          Smith Inc              20
# 231          343           Harris, Perez and Willis              49
# 232          344       Mcmillan, Gallegos and Perry              80
# 233          345                    Mitchell-Watson              29
# 234          346         Phillips, Wolfe and Martin              97
# 235          347           Hood, Hoffman and Wright              64
# 236          350           Scott, Johnson and Villa              34
# 237          351                         Berry-Mack              45
# 238          353                       Rose-Pearson              51
# 239          354                         Rowe-Arias              74
# 240          355                         Bowman LLC              48
# 241          356                       Espinoza PLC              28
# 242          357                          Carey PLC              95
# 243          358                         Cole-Ochoa              42
# 244          363                        Henry-Terry              72
# 245          365       Bray, Nguyen and Christensen              70
# 246          367                     Patel and Sons              27
# 247          368                     Smith-Villegas              65
# 248          371  Montgomery, Dominguez and Hopkins              74
# 249          372                      Elliott-Jones              41
# 250          373                        Avila Group              26
# 251          374          Pollard, Yoder and Martin               8
# 252          378                         Foster Ltd               4
# 253          380                         Nelson PLC              24
# 254          381            Cruz, Lee and Fernandez              32
# 255          384                      Rogers-Warren              89
# 256          386                        Miranda Ltd              13
# 257          387                       Barrera-Ward              64
# 258          388                         Rivera Ltd              19
# 259          389                           Hunt-Lee              54
# 260          391                        Lambert Ltd              94
# 261          393                         Steele Ltd             104
# 262          396                        Chase-Gross               3
# 263          403                      Bradley-Smith              49
# 264          404                        Schmidt Ltd              50
# 265          405            Mills, Smith and Martin              42
# 266          407                   Douglas and Sons              74
# 267          408                     Thompson-Ortiz              21
# 268          409                          Ayala LLC              46
# 269          413            Davis, Bowen and Miller              29
# 270          414                     Gonzales Group              32
# 271          417          Glover, Wilson and Hudson              86
# 272          418     Schwartz, Odonnell and Padilla               5
# 273          419          Hanson, Wilkerson and Lee              52
# 274          420                         Snyder Ltd               3
# 275          421                          Glass Inc              62
# 276          422                        Wilson-Cook              33
# 277          423                      Serrano-Lopez              48
# 278          426                     Cook-Rodriguez              32
# 279          429        Olson, Johnson and Figueroa              31
# 280          432                     Meyer and Sons              55
# 281          434                   Kennedy-Johnston              36
# 282          435            Davies, Salas and Clark              38
# 283          440                    Martinez-Graham              48
# 284          444          King, Schneider and Banks               6
# 285          446                     Nichols-Barnes              35
# 286          450                    Gibson and Sons              14
# 287          452     Roberson, Marquez and Mcdowell              25
# 288          453                          Moore LLC              21
# 289          455                         Rios Group              82
# 290          456                        Simmons PLC              13
# 291          459                          Brown Ltd              62
# 292          460     Gutierrez, Anthony and Shannon              55
# 293          461                         Murray Inc               6
# 294          463                        Carey-Ramos              33
# 295          464                         Barber Ltd              29
# 296          465                          Terry Inc              26
# 297          467          Wilson, Watkins and Moore              55
# 298          468                  Alexander-Mendoza               3
# 299          470      Bishop, Martinez and Robinson               8
# 300          471           Allen, Ramsey and Cortez              49
# 301          472                      Roach-Wheeler              17
# 302          474                       Gonzalez Inc              35
# 303          475                    Henderson Group              10
# 304          477                       Alvarado LLC              42
# 305          478             Lopez, Roach and Roach             102
# 306          480                     Brooks-Mccarty               8
# 307          483                      Bates-Johnson              30
# 308          484                       Nelson-White              75
# 309          485                     Baker-Mcdonald              99
# 310          491                    Wilkerson-Woods              68
# 311          494        Anderson, Adams and Roberts              50
# 312          495            Barker, Gibbs and Lopez              46
# 313          497                       Sparks-Berry              28
# 314          498            Jones, Ortega and Rubio             115
# 315          499                  Blankenship-Lewis             124
# 316          501                      Davis-Kennedy              88
# 317          503                    Abbott-Robinson              44
# 318          504                          Small Ltd              51
# 319          505             Sutton, Day and Brooks              39
# 320          507                         Rojas-Cook              55
# 321          508           Goodwin, Acosta and Chan              13
# 322          509                       Roth-Mathews              40
# 323          511                       Mitchell PLC              10
# 324          512                       Taylor-Lyons              40
# 325          513            Cruz, Murphy and Santos              19
# 326          514                        Roy-Hancock              43
# 327          515       Bowers, Gonzalez and Simmons              48
# 328          516           Raymond, Kelly and Yates              35
# 329          517                         Porter Inc              69
# 330          518            Hill, Davis and Stewart             106
# 331          519          Smith, James and Alvarado               7
# 332          520         Jackson, Miller and Porter              21
# 333          523         Roberts, Howard and Bender              65
# 334          524                         Torres Ltd              38
# 335          526       Harrington, Jimenez and Carr               9
# 336          527          Moran, Mcmillan and Jones              22
# 337          528                          Baird PLC              73
# 338          530           Spencer, Eaton and Young              32
# 339          531                         Miller Ltd              43
# 340          532                      Johnson-Green              47
# 341          533        Daniel, Schroeder and Morse              37
# 342          535                           Hill PLC              42
# 343          536                     Johnson-Farley               6
# 344          537                        Jones Group              18
# 345          538                           Beck Inc              52
# 346          539                       Smith-Thomas               9
# 347          540                     Randall-Wagner              33
# 348          541                       Lewis-Deleon              38
# 349          547        Walter, Gonzales and Potter              32
# 350          548            House, James and Miller              43
# 351          549          Doyle, Clark and Campbell              12
# 352          550           Phelps, Graham and Hayes              61
# 353          551       Holland, Caldwell and Oliver              48
# 354          552     Schwartz, Holland and Mccarthy              22
# 355          554                        Jackson Ltd              65
# 356          555         Valencia, Floyd and Jordan               2
# 357          556         Reyes, Houston and Esparza              52
# 358          557                          Smith PLC              37
# 359          558                         Beck Group              24
# 360          559            Young, Moran and Morris              23
# 361          563                        Daniels-Kim              90
# 362          566                         Cole-Stein              49
# 363          567                       Clark-Taylor              45
# 364          569                         Booker Ltd              15
# 365          570         Jones, Calderon and Finley              32
# 366          572                         Shaw Group              20
# 367          573                         Nelson Ltd              50
# 368          575                  Martinez and Sons              12
# 369          576                       Townsend Inc              25
# 370          577                    Taylor-Matthews              21
# 371          578                           Vega Ltd              47
# 372          582                 Wilkerson and Sons              42
# 373          583                      Martin-Wright              40
# 374          584                       Sanders-Hale              78
# 375          585                       Warren Group              26
# 376          587           Davis, Cruz and Schaefer              27
# 377          589          Boyd, Padilla and Simpson              30
# 378          590                        Adams-Young              16
# 379          591                         Miller Inc              44
# 380          592                           Chan PLC              42
# 381          593          Spencer, Gibson and Arias              16
# 382          595                      Knox and Sons              36
# 383          596          Barnes, Castro and Curtis              84
# 384          599                          Gomez LLC              34
# 385          600                          Green LLC              37
# 386          601                      Owens-Johnson              11
# 387          602                           Cole LLC              65
# 388          606        Freeman, Decker and Johnson               5
# 389          608                    Love-Montgomery              24
# 390          609                      Torres-Dunlap              87
# 391          610           Kelly, Cummings and Ward              90
# 392          611                   Williams-Manning              27
# 393          613                     Cross and Sons              17
# 394          614      Morris, Mcpherson and Edwards              14
# 395          616                      Moore-Flowers              44
# 396          619            Hopkins, Mora and Green              50
# 397          621                         Chan Group              21
# 398          623                       Williams Inc              14
# 399          625                     Whitney-Fields              29
# 400          626                        Trevino Ltd              39
# 401          630                   Mathews-Harrison              17
# 402          631         Mueller, Savage and Hudson              60
# 403          632           Oliver, Ross and Johnson              73
# 404          634                   Morgan-Blackwell              47
# 405          636                    Carroll-Stanley              21
# 406          637                      Rodriguez LLC              15
# 407          638                      Patterson Inc               5
# 408          639                   Chandler-Roberts               5
# 409          640         Cook, Jackson and Griffith              27
# 410          642                    Woodward-Jensen              50
# 411          643                          Dixon LLC              73
# 412          647                          Hayes Inc              22
# 413          650                         Pugh Group              16
# 414          653            Perry, Perez and Carter              10
# 415          655                        Smith Group             150
# 416          656                          Henry PLC              13
# 417          657                   Carpenter-Wright              35
# 418          659                     Callahan-Olsen               8
# 419          662        Morris, Mcintyre and Austin              10
# 420          664                       Caldwell PLC              59
# 421          665                        Ortega-Webb              12
# 422          668       Williams, Simpson and Waters              24
# 423          671                   Sanders and Sons              34
# 424          672     Ferguson, Henderson and Watson              43
# 425          673                     Reynolds Group              10
# 426          674                       Reid-Johnson               3
# 427          676                        Osborne LLC              24
# 428          677        Gonzalez, Dunn and Oconnell              34
# 429          678                         Ruiz-Oneal             140
# 430          683                          Pratt Ltd              13
# 431          685                     Scott and Sons              68
# 432          687                    Mcdonald-Howell              33
# 433          691          Obrien, King and Robinson              12
# 434          692          Rocha, Johnson and Dunlap              40
# 435          693                        Salazar PLC              47
# 436          694                          Avery PLC              33
# 437          697       Rodriguez, Thomas and Foster              63
# 438          698                      Hawkins-Novak              26
# 439          700                   Webster and Sons              41
# 440          701                      Pearson-Barry              44
# 441          702                      Moreno-Melton              48
# 442          703                       Pierce Group              78
# 443          705                     Brown-Stephens              96
# 444          707            Peterson, Lee and Moore              49
# 445          709                        Barry Group             179
# 446          710                        Adams-Meyer              28
# 447          712                          Payne Inc              49
# 448          713                        Bell-Newman              14
# 449          714                        Ramos Group              39
# 450          716                       Wright-Hogan              42
# 451          717                  Shepherd and Sons             116
# 452          718                     Livingston Inc              28
# 453          719                         Graham PLC              27
# 454          720              Page, Smith and Davis              29
# 455          721                     Randolph-Bauer              19
# 456          722                         Young-Luna              35
# 457          723                    Butler-Phillips              79
# 458          725             Nguyen, Chan and Brown              56
# 459          726                    Hancock-Jackson              33
# 460          729                        Bennett Inc               6
# 461          730                   Arroyo-Henderson              15
# 462          731                        Ayers-Lewis               2
# 463          732                        Mendoza LLC              31
# 464          734                  Patterson-Collins              29
# 465          735                           Koch Inc              42
# 466          736                           Reed LLC              52
# 467          737          Ballard, Stanley and Hill              42
# 468          738                          Combs Ltd              41
# 469          740                     Cunningham Ltd               3
# 470          741        Martin, Richardson and Snow              11
# 471          743             Mayer, Hawkins and Day              14
# 472          745    Martinez, Armstrong and Carroll               1
# 473          750                    Barnes and Sons              75
# 474          751          Bryant, Jacobson and West              19
# 475          752                  Butler-Richardson             104
# 476          753                     Lawrence-Clark              46
# 477          754                 Rodriguez and Sons              31
# 478          758                         Todd Group              79
# 479          760                      Frederick LLC              31
# 480          761          Abbott, Brooks and Moreno              47
# 481          762                      Simmons Group               2
# 482          763                        Manning Ltd              48
# 483          764          Villegas, Chen and Campos               8
# 484          765                        Wong-Wilson               2
# 485          766                       Parker Group              38
# 486          768          Davis, Hughes and Leblanc              87
# 487          769                        Andrews Inc               4
# 488          770                   Schneider-Suarez              92
# 489          776           Lee, Walker and Woodward              21
# 490          777             Giles, Weiss and Brown              32
# 491          778                  Blanchard-Parsons              21
# 492          779                        Maynard LLC              79
# 493          780                            Lee LLC              36
# 494          782                     Wheeler-Galvan              33
# 495          783                         Cooper LLC              90
# 496          784         Wolfe, Hull and Richardson              35
# 497          785                          Crane LLC              71
# 498          786                      Simmons-Davis              37
# 499          788                   Russell and Sons               2
# 500          789                        Blair Group              45
# 501          791                      Aguilar Group              66
# 502          792                   Rogers-Maldonado              56
# 503          793                      Thomas-Flores              42
# 504          794      Coleman, Williams and Nichols              22
# 505          795                 Rollins-Mclaughlin              28
# 506          798                         Jordan LLC              43
# 507          800         Hughes, Fuller and Sanchez              17
# 508          801                        Black Group              45
# 509          802                       Williams Inc              27
# 510          804                        Jackson Ltd              33
# 511          806                          Stone LLC              14
# 512          807          Stewart, Rocha and Torres              41
# 513          810           Austin, Griffin and Ward              59
# 514          811                       Hall-Barnett               6
# 515          814           Scott, Lopez and Baldwin              18
# 516          815                       Brown-Butler              44
# 517          816                         Dunlap Inc              18
# 518          817                        Mullins Ltd              42
# 519          824                    Howard-Williams               5
# 520          825          Smith, Lynch and Anderson              82
# 521          826          Rogers, Harmon and Gordon              96
# 522          827              Stewart, Cox and Tate              33
# 523          828                       Campbell LLC              22
# 524          831                       Figueroa Inc              10
# 525          834                          Bruce Inc              63
# 526          835                         Smith-Paul              69
# 527          836                       Phillips PLC              16
# 528          837                         Horn-House              25
# 529          839             Roth, Estrada and Vang              47
# 530          840                         Farmer Ltd              48
# 531          841                          Smith Inc              18
# 532          844                    Gallagher-Brown               3
# 533          846                         Miller Inc             111
# 534          847        Pollard, Collins and Watson              81
# 535          848                         Fisher PLC              33
# 536          849                     Brown and Sons               1
# 537          850           Cooper, Osborn and Clark              86
# 538          852                      Jones-Burnett              20
# 539          853                    Jefferson Group              33
# 540          857                    Holmes-Schaefer              36
# 541          858       Petersen, Morrison and Woods              78
# 542          861           Rogers, Robbins and Cook              87
# 543          862                        Obrien-Carr              38
# 544          863                      Johnson-Mejia              64
# 545          866                    Jones-Patterson              22
# 546          868          West, Martinez and Warren              44
# 547          870                          Mcgee PLC               1
# 548          871             Burke, Yates and Hicks              47
# 549          872                    Calderon-Torres              16
# 550          873                   Parsons and Sons              49
# 551          874                     Long-Alexander              62
# 552          875                   Mendoza-Espinoza               7
# 553          876                     Rosario-Porter              38
# 554          879                         Hughes Ltd              25
# 555          880                      Johnson-Brown              20
# 556          882       Freeman, Allen and Castaneda              20
# 557          883            Lewis, Wagner and Solis              13
# 558          885       Spears, Anderson and Huffman              51
# 559          886                    Gentry and Sons              35
# 560          887                      Preston-Smith              34
# 561          888                  Schmidt-Alexander              97
# 562          890         Simpson, Mcguire and Brown              66
# 563          892                        Flores-Wade              96
# 564          894                      Fowler-Morgan              34
# 565          896           Marquez, Reid and Kramer              11
# 566          897                     Stephens-Braun              62
# 567          898                       Wilson Group              94
# 568          899             Jackson, Lee and Hodge              15
# 569          901                         Galvan Ltd              48
# 570          902                        Parsons Ltd              19
# 571          903        Galloway, Hall and Oconnell              23
# 572          904                      Smith-Morales              55
# 573          905                          Ayers LLC              60
# 574          906                         Wright LLC              59
# 575          907                        Sanchez PLC               3
# 576          908                     Martinez-Young              48
# 577          909            Gibbs, Green and Krause              50
# 578          910                            Lee PLC              79
# 579          911                      Alexander PLC              23
# 580          912                       Morrison LLC              64
# 581          913                       Crosby Group              16
# 582          916                     Davis and Sons              18
# 583          919                         Cruz-Davis               2
# 584          920           Hudson, Spence and Perez              93
# 585          922                       Villegas Inc              19
# 586          923                      Rodriguez Inc              25
# 587          926                        Perkins Ltd              13
# 588          928                    Larson and Sons              48
# 589          929                          Allen LLC               9
# 590          930                      Cannon-Garcia              18
# 591          931                   Phillips-Bradley              28
# 592          932         Jones, Allison and Ellison              36
# 593          933                    Jimenez-Ramirez              36
# 594          934                    Nelson and Sons              37
# 595          935                    Frazier-Sanders              31
# 596          937                       Taylor Group              45
# 597          938                         Barker LLC             110
# 598          939                     Reyes and Sons               1
# 599          945                           Young-Wu               2
# 600          946        Brock, Newton and Mccormick              48
# 601          948                        House-Bates               7
# 602          949           Jackson, Howe and Gentry               9
# 603          951          Hodge, Lee and Washington              50
# 604          952        Harris, Mcdonald and Taylor              17
# 605          954                        Herrera LLC              35
# 606          958                          Patel Ltd              31
# 607          959                        Stanley PLC               4
# 608          960         Jackson, Shelton and Mayer              32
# 609          961          Davis, Sanchez and Mendez              64
# 610          962                 Galloway-Henderson              39
# 611          963                        Johnson PLC               8
# 612          964                    Graham and Sons               6
# 613          965                        Oconnor Ltd              14
# 614          967                         Miller Inc              62
# 615          968      Robinson, Schaefer and Foster              43
# 616          970           Lewis, Preston and Price              65
# 617          973                         Watson LLC              11
# 618          976     Robinson, Rodriguez and Reilly              18
# 619          977                  Anderson and Sons              23
# 620          979                           Gray PLC              57
# 621          980                        Baker Group              62
# 622          981                         Glenn-York              19
# 623          982                       Martinez PLC              21
# 624          983           Munoz, Stone and Wallace              78
# 625          984                       Gamble-Davis              44
# 626          985                           Frey PLC              26
# 627          986            Wilson, Harris and Mayo              78
# 628          987         Harris, Santos and Roberts              14
# 629          989                   Williams-Aguirre              31
# 630          990                          Jones PLC              17
# 631          993                       Mckinney Ltd              88
# 632          995                        Moore Group             106
# 633          997                     Garza-Williams              47
# 634          998                        Novak Group               7
# 635          999                          Moody Ltd              57
# 636         1000                     Jenkins-Brooks              47
